# %%
subjects=["Americans","Indians"]
verbs=["play","watch"]
objects=["Baseball","Cricket"]

# %%
for i in subjects:
    for j in verbs:
        for k in objects:
            print(i,j,k)
# Out:
# Americans play Baseball
# Americans play Cricket
# Americans watch Baseball
# Americans watch Cricket
# Indians play Baseball
# Indians play Cricket
# Indians watch Baseball
# Indians watch Cricket

# %%
def trex():
    try:
        k=int(input())
        d=5/k
        print("divisble",d)
 
    except Exception as e:
        print(e)
    else:
        print("i can divide numerator greater than zero")
    finally:
        print("above code is executable")

# %%
trex()
# Out:
#  0
# division by zero
# above code is executable

# %%
trex()
# Out:
#  3
# divisble 1.6666666666666667
# i can divide numerator greater than zero
# above code is executable

# %%
trex()
# Out:
#  dggdd
# invalid literal for int() with base 10: 'dggdd'
# above code is executable
